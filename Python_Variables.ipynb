# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/Python_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
print(x)
# Out:
# 5

# %%
y = 8

# %%
y
# Out:
# 8

# %%
x,y =(1,2)

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
print('Click "OK"')
# Out:
# Click "OK"

# %%
Numbers = [10,20,30,40]

# %%
Numbers
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# Python Variables - Exercise #1
# Create a variable with name x and a value of 10. Execute.
#
# Tell the computer to show you the value of that variable without utilizing the print() function, similar to what you would do in Jupyter.

# %%
x = 10
x
# Out:
# 10

# %% [markdown]
# Python Variables - Exercise #2
# Create a variable named x with the value 10. Then, use the print() function to display its value.

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# Python Variables - Exercise #3
# On the same line, create four new variables: a, b, c, and d, that are equal to 10, 20, 30, and 40, respectively.

# %%
a,b,c,d = 10,20,30,40

# %% [markdown]
# Python Variables - Exercise #4
# On the same line, create four new variables: a, b, c, and d, that are equal to 10, 20, 30, and 40, respectively.
#
# Tell the computer to show you the value corresponding to the variable b.
#
# Do the same for d.

# %%
a,b,c,d = 10,20,30,40
print(b)
print(d)
# Out:
# 20
# 40

# %%
x1 = 5
type(x1)
# Out:
# int

# %%
type(-6)
# Out:
# int

# %%
x2 = 4.775
type(x2)
# Out:
# float
