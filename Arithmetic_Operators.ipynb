# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/Arithmetic_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 2
# Out:
# 3

# %%
3 - 55
# Out:
# -52

# %%
15/3
# Out:
# 5.0

# %%
15/3
# Out:
# 5.0

# %%
16.0 % 3
# Out:
# 1.0

# %%
16.0/3
# Out:
# 5.333333333333333

# %%
5*3
# Out:
# 15

# %%
x = 5**3

# %%
x
# Out:
# 125

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #1
# Add the integers 15 and 23.

# %%
15 + 23
# Out:
# 38

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #2
# Subtract 50 from 26.

# %%
26 - 50
# Out:
# -24

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #3
# Divide 20 by 4.

# %%
20/4
# Out:
# 5.0

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #4
# Divide 22 by 4.

# %%
22 / 4
# Out:
# 5.5

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #5
# Obtain the remainder of the division of 22 by 4.

# %%
22 % 4
# Out:
# 2

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #6
# Divide the float 22 by 4.

# %%
float(22)/4
# Out:
# 5.5

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #7
# Multiply 6 by 8.

# %%
6 * 8
# Out:
# 48

# %% [markdown]
# Using Arithmetic Operators in Python - Exercise #8
# Raise 15 to the power of 2.

# %%
15**2
# Out:
# 225

# %%
y =5**3

# %%
y
# Out:
# 125

# %%
y == 5**3   #b== means "equals" Is y equal to 125??
# Out:
# True

# %%
y ==123
# Out:
# False

# %% [markdown]
# The Double Equality Sign - Exercise #1
# Use a double-equality sign (==) to check if 100 equals 98. Display the result without using the print() function.

# %%
100 == 98
# Out:
# False

# %% [markdown]
# How to Reassign Values - Exercise #1
# Assign the value of 14 to a variable p.

# %%
p = 14

# %% [markdown]
# How to Reassign Values - Exercise #2
# Assign the value of 14 to a variable p.
#
# Calculate p + 10.

# %%
p = 14
p+10
# Out:
# 24

# %% [markdown]
# How to Reassign Values - Exercise #3
# Now, assign 30 to the variable p.

# %%
p = 14
p = 30

# %% [markdown]
# How to Reassign Values - Exercise #4
# Calculate p + 10.

# %%
p = 30
p + 10
# Out:
# 40

# %% [markdown]
# Understanding Line Continuation - Exercise #1
# Add a backslash in the code below, so it is a one-line code. Observe the change in the result.
#
# 15 + 31
# - 26

# %%
15 + 31\
- 26
# Out:
# 20

# %% [markdown]
# Indexing Elements - Exercise #1
# Extract the letter 'B' from "Bingo!".

# %%
"Bingo!"[0]
# Out:
# 'B'
