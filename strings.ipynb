# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'George'
# Out:
# 'George'

# %%
"Jhon"
# Out:
# 'Jhon'

# %%
print("Jhon")
# Out:
# Jhon

# %%
x4 = 'George'

# %%
x4
# Out:
# 'George'

# %%
y = 10
print(str(y) + "Dollars")
# Out:
# 10Dollars

# %%
"I'm fine"
# Out:
# "I'm fine"

# %%
'I\'m fine'
# Out:
# "I'm fine"

# %%
'Press "Enter"'
# Out:
# 'Press "Enter"'

# %%
'Red ' 'car'
# Out:
# 'Red car'

# %%
print('Red ' + 'car')
# Out:
# Red car

# %%
print('Red', 'car')
# Out:
# Red car

# %%
print(4,5)
# Out:
# 4 5
