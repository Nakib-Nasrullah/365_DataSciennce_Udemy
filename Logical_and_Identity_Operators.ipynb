# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/Logical_and_Identity_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5 is 6
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_4391/2929037671.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   5 is 6
# False

# %%
5 == 6
# Out:
# False

# %%
5 is not 6
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_4391/2227521640.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   5 is not 6
# True

# %%
5 != 6
# Out:
# True

# %% [markdown]
# Logical and Identity Operators - Exercise #1
# Check whether the following code is True or False.
#
# False or not True and not False

# %%
False or not True and not False
# Out:
# False

# %% [markdown]
# Logical and Identity Operators - Exercise #2
# Check whether the following code is True or False.
#
# True and not False and True or not False

# %%
True and not False and True or not False
# Out:
# True

# %% [markdown]
# Logical and Identity Operators - Exercise #3
# Check whether the following code is True or False.
#
# True or False and False

# %%
True or False and False
# Out:
# True

# %% [markdown]
# Logical and Identity Operators - Exercise #4
# Check whether the following code is True or False.
#
# False and True or False

# %%
False and True or False
# Out:
# False

# %% [markdown]
# Logical and Identity Operators - Exercise #5
# Using an identity operator, verify that 10 is not the same as 12.

# %%
10 is not 12
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_4391/2742155778.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   10 is not 12
# True

# %% [markdown]
# Logical and Identity Operators - Exercise #6
# Using an identity operator, verify that 50 is the same as 50.
#
# This topic is covere

# %%
50 is 50
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_4391/4077015830.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   50 is 50
# True
