# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How to Create a Function with a Parameter - Exercise #1
# Define a function called multiplication_by_2(x) that returns a value equal to its argument multiplied by 2.

# %%
def multiplication_by_2(x):
    return x*2
multiplication_by_2(2)
# Out:
# 4

# %% [markdown]
# How to Create a Function with a Parameter - Exercise #2
# Define a function called division_by_2(x) that returns a float value equal to its argument divided by 2.

# %%
def division_by_2(x):
    return float(x)/2
division_by_2(10)
# Out:
# 5.0
