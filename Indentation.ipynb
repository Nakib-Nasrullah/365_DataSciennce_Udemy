# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/365_DataSciennce_Udemy/blob/main/Indentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def five(x):
  x = 5
  return x
print(five(3))
# Out:
# 5

# %% [markdown]
# Structuring with Indentation - Exercise #1
# Using indentation, write a function called ten() that takes any argument x, assigns the value 10 to x, and then returns x.
#
# Call the function with an argument of 3 and print the result.

# %%
def ten(x):
    x = 10
    return x
print(ten(3))
# Out:
# 10

# %%
10 ==20/2
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 != 11
# Out:
# True

# %%
12 > 10
# Out:
# True

# %%
22<12
# Out:
# False

# %%
12 >= 12
# Out:
# True

# %%
15 >= 10+12
# Out:
# False

# %%
15 <= 12 +12
# Out:
# True

# %% [markdown]
# Comparison Operators - Exercise #1
# Verify that 25 is smaller than 30.

# %%
25<30
# Out:
# True

# %% [markdown]
# Comparison Operators - Exercise #2
# Verify that 5 multiplied by 3 is less than or equal to 5 to the power of 3.

# %%
5*3 <= 5**3
# Out:
# True

# %% [markdown]
# Comparison Operators - Exercise #3
# Verify that 100 is equal to 10 square.

# %%
100 == 10**2
# Out:
# True

# %% [markdown]
# Comparison Operators - Exercise #4
# Verify that 53 is not equal to 46.

# %%
53 != 46
# Out:
# True

# %% [markdown]
# # **Logical Operators**

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True
